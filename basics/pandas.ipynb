# %% [markdown]
# <a href="https://colab.research.google.com/github/DaryaJavadi/data_science/blob/main/basics/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
cars = pd.Series(['BMW', 'Tesla', 'Bugatti'])
cars
# Out:
# 0        BMW
# 1      Tesla
# 2    Bugatti
# dtype: object

# %%
type(cars)
# Out:
# pandas.core.series.Series

# %%
colours = pd.Series(['Red', 'Blue', 'White'])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
cars = pd.DataFrame({'Car make': cars, 'Colour': colours})
cars
# Out:
#   Car make Colour
# 0      BMW    Red
# 1    Tesla   Blue
# 2  Bugatti  White

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Out:
# --2024-12-06 15:16:27--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2024-12-06 15:16:27 (5.90 MB/s) - ‘car-sales.csv’ saved [369/369]

# %%
df = pd.read_csv('/content/car-sales.csv')

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
df.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df[['Make', 'Colour']]
# Out:
#      Make Colour
# 0  Toyota  White
# 1   Honda    Red
# 2  Toyota   Blue
# 3     BMW  Black
# 4  Nissan  White
# 5  Toyota  Green
# 6   Honda   Blue
# 7   Honda   Blue
# 8  Toyota  White
# 9  Nissan  White

# %%
df[(df['Make'] == 'Toyota') & (df['Odometer (KM)'] < 70000)]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
df.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
df.sum(numeric_only = True)
# Out:
# Odometer (KM)    786014
# Doors                40
# dtype: int64

# %%
df.mean(numeric_only = True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
df.groupby(['Make', 'Colour']).mean(numeric_only = True)
# Out:
#                Odometer (KM)  Doors
# Make   Colour
# BMW    Black         11179.0    5.0
# Honda  Blue          50218.0    4.0
#        Red           87899.0    4.0
# Nissan White        122347.5    4.0
# Toyota Blue          32549.0    3.0
#        Green         99213.0    4.0
#        White        105021.5    4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
df['Make'].value_counts()
# Out:
# Make
# Toyota    4
# Honda     3
# Nissan    2
# BMW       1
# Name: count, dtype: int64

# %%
df['Odometer (Mile)'] = df['Odometer (KM)'] / 1.6
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000

# %%
df = df.drop('Odometer (Mile)', axis = 1)

# %%
# df.drop('Odometer (Mile)', axis = 1, inplace = True)
# df
# df.drop('is_car', axis = 1, inplace = True)

# %%
df['Car Engine'] = pd.Series([3.2, 4.5, 2.3, 5.3, 4.6])
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Car Engine
# 0  Toyota  White         150043      4   $4,000.00         3.2
# 1   Honda    Red          87899      4   $5,000.00         4.5
# 2  Toyota   Blue          32549      3   $7,000.00         2.3
# 3     BMW  Black          11179      5  $22,000.00         5.3
# 4  Nissan  White         213095      4   $3,500.00         4.6
# 5  Toyota  Green          99213      4   $4,500.00         NaN
# 6   Honda   Blue          45698      4   $7,500.00         NaN
# 7   Honda   Blue          54738      4   $7,000.00         NaN
# 8  Toyota  White          60000      4   $6,250.00         NaN
# 9  Nissan  White          31600      4   $9,700.00         NaN

# %%
df['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
df['Odometer (Mile)']=df['Odometer (KM)'].apply(lambda x:x/1.6)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Car Engine  \
# 0  Toyota  White         150043      4   $4,000.00         3.2
# 1   Honda    Red          87899      4   $5,000.00         4.5
# 2  Toyota   Blue          32549      3   $7,000.00         2.3
# 3     BMW  Black          11179      5  $22,000.00         5.3
# 4  Nissan  White         213095      4   $3,500.00         4.6
# 5  Toyota  Green          99213      4   $4,500.00         NaN
# 6   Honda   Blue          45698      4   $7,500.00         NaN
# 7   Honda   Blue          54738      4   $7,000.00         NaN
# 8  Toyota  White          60000      4   $6,250.00         NaN
# 9  Nissan  White          31600      4   $9,700.00         NaN
#
#    Odometer (Mile)
# 0        93776.875
# 1        54936.875
# 2        20343.125
# 3         6986.875
# 4       133184.375
# 5        62008.125
# 6        28561.250
# 7        34211.250
# 8        37500.000
# 9        19750.000

# %%
def currency(x):
    if '$' in x:
      return 'USD'
    else:
      return 'unknown'
df['Currency']=df['Price'].apply(currency)
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Car Engine  \
# 0  Toyota  White         150043      4   $4,000.00         3.2
# 1   Honda    Red          87899      4   $5,000.00         4.5
# 2  Toyota   Blue          32549      3   $7,000.00         2.3
# 3     BMW  Black          11179      5  $22,000.00         5.3
# 4  Nissan  White         213095      4   $3,500.00         4.6
# 5  Toyota  Green          99213      4   $4,500.00         NaN
# 6   Honda   Blue          45698      4   $7,500.00         NaN
# 7   Honda   Blue          54738      4   $7,000.00         NaN
# 8  Toyota  White          60000      4   $6,250.00         NaN
# 9  Nissan  White          31600      4   $9,700.00         NaN
#
#    Odometer (Mile) Currency
# 0        93776.875      USD
# 1        54936.875      USD
# 2        20343.125      USD
# 3         6986.875      USD
# 4       133184.375      USD
# 5        62008.125      USD
# 6        28561.250      USD
# 7        34211.250      USD
# ...

# %%
df.drop([1, 5, 2], axis = 0)
# df.drop([1, 5, 2])
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Car Engine  \
# 0  Toyota  White         150043      4   $4,000.00         3.2
# 3     BMW  Black          11179      5  $22,000.00         5.3
# 4  Nissan  White         213095      4   $3,500.00         4.6
# 6   Honda   Blue          45698      4   $7,500.00         NaN
# 7   Honda   Blue          54738      4   $7,000.00         NaN
# 8  Toyota  White          60000      4   $6,250.00         NaN
# 9  Nissan  White          31600      4   $9,700.00         NaN
#
#    Odometer (Mile) Currency
# 0        93776.875      USD
# 3         6986.875      USD
# 4       133184.375      USD
# 6        28561.250      USD
# 7        34211.250      USD
# 8        37500.000      USD
# 9        19750.000      USD

# %%
df['Price'] = df['Price'].str.replace('[/$/,/.]', '', regex = True)
# / -> or menasini verir, regex ile yoxluyur, yerine '' hecne verir

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 0  Toyota  White         150043      4   400000         3.2        93776.875
# 1   Honda    Red          87899      4   500000         4.5        54936.875
# 2  Toyota   Blue          32549      3   700000         2.3        20343.125
# 3     BMW  Black          11179      5  2200000         5.3         6986.875
# 4  Nissan  White         213095      4   350000         4.6       133184.375
# 5  Toyota  Green          99213      4   450000         NaN        62008.125
# 6   Honda   Blue          45698      4   750000         NaN        28561.250
# 7   Honda   Blue          54738      4   700000         NaN        34211.250
# 8  Toyota  White          60000      4   625000         NaN        37500.000
# 9  Nissan  White          31600      4   970000         NaN        19750.000
#
#   Currency
# 0      USD
# 1      USD
# 2      USD
# 3      USD
# 4      USD
# 5      USD
# 6      USD
# 7      USD
# ...

# %%
df['Price'] = df['Price'].astype(int)
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 0  Toyota  White         150043      4   400000         3.2        93776.875
# 1   Honda    Red          87899      4   500000         4.5        54936.875
# 2  Toyota   Blue          32549      3   700000         2.3        20343.125
# 3     BMW  Black          11179      5  2200000         5.3         6986.875
# 4  Nissan  White         213095      4   350000         4.6       133184.375
# 5  Toyota  Green          99213      4   450000         NaN        62008.125
# 6   Honda   Blue          45698      4   750000         NaN        28561.250
# 7   Honda   Blue          54738      4   700000         NaN        34211.250
# 8  Toyota  White          60000      4   625000         NaN        37500.000
# 9  Nissan  White          31600      4   970000         NaN        19750.000
#
#   Currency
# 0      USD
# 1      USD
# 2      USD
# 3      USD
# 4      USD
# 5      USD
# 6      USD
# 7      USD
# ...

# %%
df['Price'] = df['Price']/100
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 0  Toyota  White         150043      4   4000.0         3.2        93776.875
# 1   Honda    Red          87899      4   5000.0         4.5        54936.875
# 2  Toyota   Blue          32549      3   7000.0         2.3        20343.125
# 3     BMW  Black          11179      5  22000.0         5.3         6986.875
# 4  Nissan  White         213095      4   3500.0         4.6       133184.375
# 5  Toyota  Green          99213      4   4500.0         NaN        62008.125
# 6   Honda   Blue          45698      4   7500.0         NaN        28561.250
# 7   Honda   Blue          54738      4   7000.0         NaN        34211.250
# 8  Toyota  White          60000      4   6250.0         NaN        37500.000
# 9  Nissan  White          31600      4   9700.0         NaN        19750.000
#
#   Currency
# 0      USD
# 1      USD
# 2      USD
# 3      USD
# 4      USD
# 5      USD
# 6      USD
# 7      USD
# ...

# %%
df_copy = df.copy()
df_copy
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 0  Toyota  White         150043      4   4000.0         3.2        93776.875
# 1   Honda    Red          87899      4   5000.0         4.5        54936.875
# 2  Toyota   Blue          32549      3   7000.0         2.3        20343.125
# 3     BMW  Black          11179      5  22000.0         5.3         6986.875
# 4  Nissan  White         213095      4   3500.0         4.6       133184.375
# 5  Toyota  Green          99213      4   4500.0         NaN        62008.125
# 6   Honda   Blue          45698      4   7500.0         NaN        28561.250
# 7   Honda   Blue          54738      4   7000.0         NaN        34211.250
# 8  Toyota  White          60000      4   6250.0         NaN        37500.000
# 9  Nissan  White          31600      4   9700.0         NaN        19750.000
#
#   Currency
# 0      USD
# 1      USD
# 2      USD
# 3      USD
# 4      USD
# 5      USD
# 6      USD
# 7      USD
# ...

# %%
df.to_csv('var_processed.csv', index = False)

# %%
df.to_csv('/content/var_processed.csv')

# %%
df.sort_values(by = 'Price')
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 4  Nissan  White         213095      4   3500.0         4.6       133184.375
# 0  Toyota  White         150043      4   4000.0         3.2        93776.875
# 5  Toyota  Green          99213      4   4500.0         NaN        62008.125
# 1   Honda    Red          87899      4   5000.0         4.5        54936.875
# 8  Toyota  White          60000      4   6250.0         NaN        37500.000
# 2  Toyota   Blue          32549      3   7000.0         2.3        20343.125
# 7   Honda   Blue          54738      4   7000.0         NaN        34211.250
# 6   Honda   Blue          45698      4   7500.0         NaN        28561.250
# 9  Nissan  White          31600      4   9700.0         NaN        19750.000
# 3     BMW  Black          11179      5  22000.0         5.3         6986.875
#
#   Currency
# 4      USD
# 0      USD
# 5      USD
# 1      USD
# 8      USD
# 2      USD
# 7      USD
# 6      USD
# ...

# %%
df.sort_values(by = 'Price', ascending = False)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 3     BMW  Black          11179      5  22000.0         5.3         6986.875
# 9  Nissan  White          31600      4   9700.0         NaN        19750.000
# 6   Honda   Blue          45698      4   7500.0         NaN        28561.250
# 2  Toyota   Blue          32549      3   7000.0         2.3        20343.125
# 7   Honda   Blue          54738      4   7000.0         NaN        34211.250
# 8  Toyota  White          60000      4   6250.0         NaN        37500.000
# 1   Honda    Red          87899      4   5000.0         4.5        54936.875
# 5  Toyota  Green          99213      4   4500.0         NaN        62008.125
# 0  Toyota  White         150043      4   4000.0         3.2        93776.875
# 4  Nissan  White         213095      4   3500.0         4.6       133184.375
#
#   Currency
# 3      USD
# 9      USD
# 6      USD
# 2      USD
# 7      USD
# 8      USD
# 1      USD
# 5      USD
# ...

# %%
df.sort_values(by = 'Price', ascending = False).reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Car Engine  \
# 0      3     BMW  Black          11179      5  22000.0         5.3
# 1      9  Nissan  White          31600      4   9700.0         NaN
# 2      6   Honda   Blue          45698      4   7500.0         NaN
# 3      2  Toyota   Blue          32549      3   7000.0         2.3
# 4      7   Honda   Blue          54738      4   7000.0         NaN
# 5      8  Toyota  White          60000      4   6250.0         NaN
# 6      1   Honda    Red          87899      4   5000.0         4.5
# 7      5  Toyota  Green          99213      4   4500.0         NaN
# 8      0  Toyota  White         150043      4   4000.0         3.2
# 9      4  Nissan  White         213095      4   3500.0         4.6
#
#    Odometer (Mile) Currency
# 0         6986.875      USD
# 1        19750.000      USD
# 2        28561.250      USD
# 3        20343.125      USD
# 4        34211.250      USD
# 5        37500.000      USD
# ...

# %%
df.sort_values(by = 'Price', ascending = False).reset_index(drop = True)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 0     BMW  Black          11179      5  22000.0         5.3         6986.875
# 1  Nissan  White          31600      4   9700.0         NaN        19750.000
# 2   Honda   Blue          45698      4   7500.0         NaN        28561.250
# 3  Toyota   Blue          32549      3   7000.0         2.3        20343.125
# 4   Honda   Blue          54738      4   7000.0         NaN        34211.250
# 5  Toyota  White          60000      4   6250.0         NaN        37500.000
# 6   Honda    Red          87899      4   5000.0         4.5        54936.875
# 7  Toyota  Green          99213      4   4500.0         NaN        62008.125
# 8  Toyota  White         150043      4   4000.0         3.2        93776.875
# 9  Nissan  White         213095      4   3500.0         4.6       133184.375
#
#   Currency
# 0      USD
# 1      USD
# 2      USD
# 3      USD
# 4      USD
# 5      USD
# 6      USD
# 7      USD
# ...

# %%
df.drop_duplicates()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 0  Toyota  White         150043      4   4000.0         3.2        93776.875
# 1   Honda    Red          87899      4   5000.0         4.5        54936.875
# 2  Toyota   Blue          32549      3   7000.0         2.3        20343.125
# 3     BMW  Black          11179      5  22000.0         5.3         6986.875
# 4  Nissan  White         213095      4   3500.0         4.6       133184.375
# 5  Toyota  Green          99213      4   4500.0         NaN        62008.125
# 6   Honda   Blue          45698      4   7500.0         NaN        28561.250
# 7   Honda   Blue          54738      4   7000.0         NaN        34211.250
# 8  Toyota  White          60000      4   6250.0         NaN        37500.000
# 9  Nissan  White          31600      4   9700.0         NaN        19750.000
#
#   Currency
# 0      USD
# 1      USD
# 2      USD
# 3      USD
# 4      USD
# 5      USD
# 6      USD
# 7      USD
# ...

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-missing-data.csv
# Out:
# --2024-12-06 15:16:28--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-missing-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287 [text/plain]
# Saving to: ‘car-sales-missing-data.csv’
#
# car-sales-missing-d 100%[===================>]     287  --.-KB/s    in 0s
#
# 2024-12-06 15:16:28 (15.2 MB/s) - ‘car-sales-missing-data.csv’ saved [287/287]

# %%
car_sales_missing = pd.read_csv('/content/car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.isna().sum()
# car_sales_missing.isna().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing.dropna(subset = ['Price'], inplace = True)

# %%
car_sales_missing['Odometer'].mean()
# Out:
# 98763.2

# %%
car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   98763.2    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   98763.2    4.0   $4,500
# 6   Honda    NaN   98763.2    4.0   $7,500
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Colour'].mode()[0]
# Out:
# 'White'

# %%
car_sales_missing['Colour'].fillna(car_sales_missing['Colour'].mode()[0])
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6    White
# 9    White
# Name: Colour, dtype: object

# %%
# df.Colour is also can shiow the table as df.['Colour']

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 0  Toyota  White         150043      4   4000.0         3.2        93776.875
# 1   Honda    Red          87899      4   5000.0         4.5        54936.875
# 2  Toyota   Blue          32549      3   7000.0         2.3        20343.125
# 3     BMW  Black          11179      5  22000.0         5.3         6986.875
# 4  Nissan  White         213095      4   3500.0         4.6       133184.375
# 5  Toyota  Green          99213      4   4500.0         NaN        62008.125
# 6   Honda   Blue          45698      4   7500.0         NaN        28561.250
# 7   Honda   Blue          54738      4   7000.0         NaN        34211.250
# 8  Toyota  White          60000      4   6250.0         NaN        37500.000
# 9  Nissan  White          31600      4   9700.0         NaN        19750.000
#
#   Currency
# 0      USD
# 1      USD
# 2      USD
# 3      USD
# 4      USD
# 5      USD
# 6      USD
# 7      USD
# ...

# %%
df.sample(frac = 0.3)
# random verir
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Car Engine  Odometer (Mile)  \
# 5  Toyota  Green          99213      4  4500.0         NaN        62008.125
# 7   Honda   Blue          54738      4  7000.0         NaN        34211.250
# 0  Toyota  White         150043      4  4000.0         3.2        93776.875
#
#   Currency
# 5      USD
# 7      USD
# 0      USD

# %%
df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price               22000.0
# Car Engine              5.3
# Odometer (Mile)    6986.875
# Currency                USD
# Name: 3, dtype: object

# %%
df.iloc[[3, 5, 7]]
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Car Engine  Odometer (Mile)  \
# 3     BMW  Black          11179      5  22000.0         5.3         6986.875
# 5  Toyota  Green          99213      4   4500.0         NaN        62008.125
# 7   Honda   Blue          54738      4   7000.0         NaN        34211.250
#
#   Currency
# 3      USD
# 5      USD
# 7      USD

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Odometer (KM)'}>,
#         <Axes: title={'center': 'Doors'}>],
#        [<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Car Engine'}>],
#        [<Axes: title={'center': 'Odometer (Mile)'}>, <Axes: >]],
#       dtype=object)

# %%
# tablellari birlesdirmek
# pd.merge(table_A, table_B, left_on = 'id1' right_on = 'id2', how = 'right')

# %%
# df.rename(columns = {'Odometer (KM)': 'Odometer'}, inplace = True)
