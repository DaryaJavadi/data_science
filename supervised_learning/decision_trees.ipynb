# %% [markdown]
# <a href="https://colab.research.google.com/github/DaryaJavadi/data_science/blob/main/supervised_learning/decision_trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

iris = load_iris(as_frame = True)
X_iris = iris.data[["petal length (cm)", "petal width (cm)"]].values
y_iris = iris.target

tree_clf = DecisionTreeClassifier(max_depth = 2, random_state = 42)
tree_clf.fit(X_iris, y_iris)
tree_clf.score(X_iris, y_iris)
# Out:
# 0.96

# %%
tree.plot_tree(tree_clf);

# %%
tree_clf.predict_proba([[5, 1.5]]).round(3)
# Out:
# array([[0.   , 0.907, 0.093]])

# %%
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

X_moons, y_moons = make_moons(n_samples = 100, noise = 0.2, random_state = 42)

tree_clf1 = DecisionTreeClassifier(random_state = 42, min_samples_leaf = 5)
tree_clf2 = DecisionTreeClassifier(random_state = 42)

tree_clf1.fit(X_moons, y_moons)
tree_clf2.fit(X_moons, y_moons)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
tree_clf1.score(X_moons, y_moons), tree_clf2.score(X_moons, y_moons)
# Out:
# (0.97, 1.0)

# %% [markdown]
# #Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np

np.random.seed(42)
X_quad = np.random.rand(200, 1) - 0.5
y_quad = X_quad ** 2 + 0.025 *  np.random.randn(200, 1)

tree_reg = DecisionTreeRegressor(max_depth = 3, random_state = 42)
tree_reg.fit(X_quad, y_quad)
tree_reg.score(X_quad, y_quad)
# Out:
# 0.886898947978226

# %%
tree.plot_tree(tree_reg);

# %%
import matplotlib.pyplot as plt

X_new = np.linspace(-0.5, 0.5, 100).reshape(-1, 1)
y_pred = tree_reg.predict(X_new)

plt.plot(X_quad, y_quad, 'b.')
plt.plot(X_new, y_pred, "r-", linewidth = 2)
plt.xlabel("$x_1$")
plt.ylabel("$y$")
plt.grid()
plt.show()

# %%
np.linspace(-0.5, 0.5, 100).reshape(100, 1).shape
# Out:
# (100, 1)
